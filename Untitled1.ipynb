# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
X_train.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_train[:5]
# Out:
# array([[6],
#        [9],
#        [9],
#        [4],
#        [1]], dtype=uint8)

# %%
y_train = y_train.reshape(-1,)
y_train[:5]
# Out:
# array([6, 9, 9, 4, 1], dtype=uint8)

# %%
y_test = y_test.reshape(-1,)

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
def plot_sample(X, y, index):
    plt.figure(figsize = (15,2))
    plt.imshow(X[index])
    plt.xlabel(classes[y[index]])

# %%
plot_sample(X_train, y_train, 5)

# %%
plot_sample(X_train, y_train, 3)

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
ann = models.Sequential([
        layers.Flatten(input_shape=(32,32,3)),
        layers.Dense(3000, activation='relu'),
        layers.Dense(1000, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])

ann.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

ann.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 155s 98ms/step - loss: 1.8091 - accuracy: 0.3548
# Epoch 2/5
# 1563/1563 [==============================] - 144s 92ms/step - loss: 1.6228 - accuracy: 0.4277
# Epoch 3/5
# 1563/1563 [==============================] - 143s 91ms/step - loss: 1.5397 - accuracy: 0.4548
# Epoch 4/5
# 1563/1563 [==============================] - 142s 91ms/step - loss: 1.4802 - accuracy: 0.4795
# Epoch 5/5
# 1563/1563 [==============================] - 142s 91ms/step - loss: 1.4295 - accuracy: 0.4961

# %%
from sklearn.metrics import confusion_matrix , classification_report
import numpy as np
y_pred = ann.predict(X_test)
y_pred_classes = [np.argmax(element) for element in y_pred]

print("Classification Report: \n", classification_report(y_test, y_pred_classes))
# Out:
# 313/313 [==============================] - 9s 29ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.46      0.65      0.53      1000
#            1       0.79      0.26      0.39      1000
#            2       0.47      0.16      0.24      1000
#            3       0.28      0.48      0.35      1000
#            4       0.41      0.41      0.41      1000
#            5       0.32      0.45      0.37      1000
#            6       0.58      0.39      0.47      1000
#            7       0.40      0.69      0.51      1000
#            8       0.61      0.54      0.57      1000
#            9       0.66      0.36      0.46      1000
#
#     accuracy                           0.44     10000
#    macro avg       0.50      0.44      0.43     10000
# weighted avg       0.50      0.44      0.43     10000

# %%
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
cnn.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 82s 52ms/step - loss: 1.4632 - accuracy: 0.4740
# Epoch 2/10
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.1296 - accuracy: 0.6028
# Epoch 3/10
# 1563/1563 [==============================] - 75s 48ms/step - loss: 0.9973 - accuracy: 0.6539
# Epoch 4/10
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.9076 - accuracy: 0.6857
# Epoch 5/10
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.8429 - accuracy: 0.7095
# Epoch 6/10
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.7820 - accuracy: 0.7295
# Epoch 7/10
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.7353 - accuracy: 0.7466
# Epoch 8/10
# 1563/1563 [==============================] - 75s 48ms/step - loss: 0.6866 - accuracy: 0.7618
# Epoch 9/10
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6430 - accuracy: 0.7773
# Epoch 10/10
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.6052 - accuracy: 0.7887

# %%
cnn.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 6s 17ms/step - loss: 0.9336 - accuracy: 0.6921
# [0.9335681796073914, 0.6920999884605408]

# %%
y_pred = cnn.predict(X_test)
y_pred[:5]
# Out:
# 313/313 [==============================] - 6s 19ms/step

# %%
y_classes = [np.argmax(element) for element in y_pred]
y_classes[:5]

# %%
y_test[:5]

# %%
plot_sample(X_test, y_test,3)

# %%
classes[y_classes[3]]
